# %% [markdown]
# <a href="https://colab.research.google.com/github/Adityaaa7/Techathon_671/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## import librariess
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load dataset

df = pd.read_csv("aissms_final.csv")

# %%
df.head()
# Out:
#    Sample_ID  Acetone_ppm  Nitric_Oxide_ppb  Isoprene_ppb  Ammonia_ppm  \
# 0          1     2.133278         18.640061     83.311138     1.167690
# 1          2     2.017043         18.122891     76.166971     1.914467
# 2          3     2.123450         12.224487     76.835453     1.079212
# 3          4     1.935946         25.389038    131.085616     1.305074
# 4          5     2.020293         11.939097     69.235936     1.791997
#
#    Methane_ppm  Hydrogen_Sulfide_ppb  Carbon_Monoxide_ppm  Hydrogen_ppm  \
# 0     1.893513              3.423898             1.458482      8.013801
# 1     2.245576              5.601198             1.968447     11.784556
# 2     2.298651              6.995094             2.159404      9.647346
# 3     1.228298              2.026256             3.322116     11.381720
# 4     1.497074              2.754855             1.739973     10.643207
#
#    Ethanol_ppb Disease_Label
# 0    27.129363        Asthma
# 1    66.843977          SIBO
# ...

# %%
df.shape
# Out:
# (2500, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Sample_ID             2500 non-null   int64
#  1   Acetone_ppm           2500 non-null   float64
#  2   Nitric_Oxide_ppb      2500 non-null   float64
#  3   Isoprene_ppb          2500 non-null   float64
#  4   Ammonia_ppm           2500 non-null   float64
#  5   Methane_ppm           2500 non-null   float64
#  6   Hydrogen_Sulfide_ppb  2500 non-null   float64
#  7   Carbon_Monoxide_ppm   2500 non-null   float64
#  8   Hydrogen_ppm          2500 non-null   float64
#  9   Ethanol_ppb           2500 non-null   float64
#  10  Disease_Label         2500 non-null   object
# dtypes: float64(9), int64(1), object(1)
# memory usage: 215.0+ KB

# %%
df.isnull().sum()
# Out:
# Sample_ID               0
# Acetone_ppm             0
# Nitric_Oxide_ppb        0
# Isoprene_ppb            0
# Ammonia_ppm             0
# Methane_ppm             0
# Hydrogen_Sulfide_ppb    0
# Carbon_Monoxide_ppm     0
# Hydrogen_ppm            0
# Ethanol_ppb             0
# Disease_Label           0
# dtype: int64

# %%
df["Disease_Label"].value_counts()
# Out:
# Disease_Label
# Healthy        1446
# SIBO            500
# Lung_Cancer     291
# COPD            116
# Diabetes         90
# Asthma           57
# Name: count, dtype: int64

# %%
df['Disease_Label'].unique()
# Out:
# array(['Asthma', 'SIBO', 'Diabetes', 'Healthy', 'COPD', 'Lung_Cancer'],
#       dtype=object)

# %%
# Split into features & labels
X = df.drop(columns=["Disease_Label"])  # Features
y = df["Disease_Label"]  # Target

# %%
# Train-test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Train model
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=400, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=400, random_state=42)

# %%
# Evaluate accuracy

from sklearn.metrics import accuracy_score
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.2f}")
# Out:
# Model Accuracy: 0.86

# %%
model.predict([[1,2.13,18.64,83.31,1.16,1.89,3.42,1.45,8.01,27.12]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Asthma'], dtype=object)

# %%
import pickle
pickle.dump(model,open('model_last.pkl','wb'))
